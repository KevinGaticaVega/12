# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinGaticaVega/12/blob/main/Copy_of_StableDiffusionUI_Voldemort_V2_0_OhSoo_copy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/AUTOMATIC1111/stable-diffusion-webui

# %% [markdown]
# A little side note:
# The extension tab only works if localtunnel is enabled

# %% [markdown]
# **Colab was created by user: daswer123**  e modificado pelo mikeinha menino mau
#
# https://github.com/daswer123/stable-diffusion-colab
#
# **If you liked the colab, give it a star :)**
#
#
# **OBSERVATION/OBSERVAÇÃO:**
#
#
# ENGLISH:
#
# IF YOU WANT TO USE ONLY STABLE DIFFUSION 2.1, ONLY EXECUTE ITS CELL. IF YOU WANT TO USE OTHER MODELS ALONG WITH SD2.1, EXECUTE THE CELLS BY THIS ORDER: 1-4-3.
#
#
# PT-BR
#
# CASO QUEIRA USAR APENAS O STABLE DIFFUSION 2.1, EXECUTE APENAS A CÉLULA DO MESMO. CASO QUEIRA OUTROS MODELOS JUNTO COM O SD 2.1, EXECUTE AS CÉLULAS NA SEGUINTE ORDEM: 1-4-3.

# %%
# !python --version

# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py39_4.9.2-Linux-x86_64.sh
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# !conda install -q -y jupyter
# !conda install -q -y google-colab -c conda-forge
# !python -m ipykernel install --name "py39" --user

# !python --version


# %cd /content/
#@title ## Setup Stable Diffusion by AUTOMATIC1111! (1) { display-mode: "form" }

#@markdown Full loading of all components takes about 7-8 minutes
#@markdown 
#@markdown O carregamento leva de 7 a 8 minutos.

#@markdown ##Download model:
Model = "waifu-diffusion 1.3 release" #@param ["Stable-diffusion 1.4","Stable-diffusion 1.5 + inpaint model","nai","Anything 3.0","BerryMix zeipher222", "waifu-diffusion 1.3 release"]

#@markdown ##Gdrive:
#@markdown #####If you select gdrive, the model will not be downloaded, but copied from your drive
#@markdown 
#@markdown Se selecionar o Google Drive, o modelo não será baixado, mas copiado do seu Drive.
mount_gdrive = True #@param{type:"boolean"}
#@markdown #####Write the folder or theass as path to the folder, you can leave the field blank if the model is in the root of the drive
#@markdown 
#@markdown Escreva o caminho da pasta onde está o modelo aqui. Se estiver na raiz do GDrive, deixe em branco.
gdrive_path = "SD_models/f222.ckpt" #@param {type:"string"}
#@markdown Your path look like /content/drive/MyDrive/**gdrive_path**

#@markdown ##Extra
#@markdown xformers increases the generation speed by 1.5 - 3 times, on T4 the generation speed increases by 1.5 times 
install_xformers = True #@param{type:"boolean"}
download_hypernetworks_modules = False #@param{type:"boolean"}
#@markdown ##### If you do not want to load the model from google disk, but want to connect it for example to display pictures, then select this checkbox
mount_gdrive_for_outputs = False #@param{type:"boolean"}
#@markdown ##### install outpaint/inpaint module, launch only with localtunnel, put webui localtunnel link in setting without http  
outpaint_inpaint_module = False #@param{type:"boolean"}

import time

if mount_gdrive == True or mount_gdrive_for_outputs == True:
  from google.colab import drive
  drive.mount('/content/drive')

# !nvidia-smi
# !ls /usr/share/fonts/truetype/
# !npm install -g localtunnel
# !pip install tensorflow
# !pip install tensorflow_io
# !pip install gdown
# !pip install git+https://github.com/KichangKim/DeepDanbooru.git@edf73df4cdaeea2cf00e9ac08bd8a9026b7a7b26
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# %cd /content/stable-diffusion-webui
# !git reset --hard c30c06db207a580d76544fd10fc1e03cd58ce85e
# !pip install -r requirements.txt
# !mkdir repositories
# !git clone https://github.com/CompVis/stable-diffusion.git repositories/stable-diffusion
# !git clone https://github.com/CompVis/taming-transformers.git repositories/taming-transformers
# !git clone https://github.com/sczhou/CodeFormer.git repositories/CodeFormer
# !git clone https://github.com/salesforce/BLIP.git repositories/BLIP
# !pip install -r repositories/CodeFormer/requirements.txt
# !git clone https://github.com/crowsonkb/k-diffusion repositories/k-diffusion
# !pip install clip



# %cd /content/stable-diffusion-webui
if mount_gdrive == True:
    new_gdrive_path = "/content/drive/MyDrive/" + gdrive_path
    # !cp $new_gdrive_path /content/stable-diffusion-webui/models/Stable-diffusion/
else:
    if(Model == "Stable-diffusion 1.4"):
      user_header = f"\"Authorization: Bearer {'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'}\""
      # !wget --header={user_header} https://huggingface.co/CompVis/stable-diffusion-v-1-4-original/resolve/main/sd-v1-4.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/model1_4.ckpt
    elif(Model == "Stable-diffusion 1.5 + inpaint model"):
      user_header = f"\"Authorization: Bearer {'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'}\""
      # !wget --header={user_header} https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5.ckpt
      # !wget --header={user_header} https://huggingface.co/runwayml/stable-diffusion-inpainting/resolve/main/sd-v1-5-inpainting.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5-inpainting.ckpt
      #VAE
      # !wget --header={user_header} https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5.vae.pt
      # !wget --header={user_header} https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5-inpainting.vae.pt
    elif(Model == "Anything 3.0"):
        # !gdown https://huggingface.co/Daswer123/misc_models/resolve/main/Anything-V3.0-pruned-fp32.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/anything3_0.ckpt
        # !gdown https://huggingface.co/Daswer123/misc_models/resolve/main/Anything-V3.0.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/anything3_0.vae.pt
    elif(Model == "BerryMix zeipher222"):
        # !gdown https://huggingface.co/Daswer123/misc_models/resolve/main/Anything-V3.0-pruned-fp32.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/BerryMix_zeipher222.ckpt
        # !gdown https://huggingface.co/Daswer123/misc_models/resolve/main/Anything-V3.0.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/BerryMix_zeipher222.vae.pt
    elif(Model == "waifu-diffusion 1.3 release"):
        # !gdown https://huggingface.co/hakurei/waifu-diffusion-v1-3/resolve/main/wd-v1-3-float32.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/waiffu_diffusion1_3.ckpt
    elif(Model == "nai"):
        # !gdown https://huggingface.co/Daswer123/gfdsa/resolve/main/model.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/nai.ckpt
        # !gdown https://huggingface.co/Daswer123/gfdsa/resolve/main/vae_vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/nai.vae.pt
        # !gdown https://huggingface.co/Daswer123/raw/resolve/main/config.yaml -O /content/stable-diffusion-webui/models/Stable-diffusion/nai.yaml
        # !gdown https://huggingface.co/Daswer123/gfdsa/resolve/main/v2.pt -O /content/stable-diffusion-webui/v2.pt
        # !gdown https://huggingface.co/Daswer123/gfdsa/raw/main/v2enabler.py -O /content/stable-diffusion-webui/scripts/v2enable.py
        # %cd /content/stable-diffusion-webui
        # !wget https://pastebin.com/raw/ukEFznTb -O /content/stable-diffusion-webui/ui-config.json
        # !wget https://pastebin.com/raw/8u0Dw37P -O /content/stable-diffusion-webui/config.json
        # !git clone "https://github.com/DominikDoom/a1111-sd-webui-tagcomplete.git" extensions/tag-autocomplete
    else:
        # !gdown https://drive.google.com/uc?id=1EdZmlteF8EThBu9Rpf2JMRFSLbVD7EXa -O /content/stable-diffusion-webui/model.ckpt

if(download_hypernetworks_modules == True):
  # %cd /content/stable-diffusion-webui/models/
  # !gdown https://huggingface.co/Daswer123/gfdsa/resolve/main/hypernetworks.zip -O /content/stable-diffusion-webui/models/hypernetworks.zip 
  # !unzip /content/stable-diffusion-webui/models/hypernetworks.zip 

#Instal xformers
#Increases generation speed 

#Need for xformers

if (install_xformers):
  # %cd /content/stable-diffusion-webui/
  # !mkdir repositories
  # %cd /content/stable-diffusion-webui/repositories
  # !git clone https://github.com/openai/triton.git
  # %cd triton/python
  # !pip install -e .
  
  # %cd /notebooks/stable-diffusion-webui/repositories/
  # !git clone https://github.com/facebookresearch/xformers.git
  # %cd xformers
  # !git submodule update --init --recursive
  # !pip install -r requirements.txt
  
  from IPython.display import clear_output
  import time
  from IPython.display import HTML
  from subprocess import getoutput
  import os
  s = getoutput('nvidia-smi')
  if 'T4' in s:
    gpu = 'T4'
  elif 'P100' in s:
    gpu = 'P100'
  elif 'V100' in s:
    gpu = 'V100'
  elif 'A100' in s:
    gpu = 'A100'
  
  if (gpu=='T4'):
    # %pip install https://github.com/daswer123/stable-diffusion-colab/raw/main/xformers%20prebuild/T4/python39/xformers-0.0.14.dev0-cp39-cp39-linux_x86_64.whl
    
  elif (gpu=='P100'):
    # %pip install -q https://github.com/TheLastBen/fast-stable-diffusion/raw/main/precompiled/P100/xformers-0.0.13.dev0-py3-none-any.whl
  
  elif (gpu=='V100'):
    # %pip install -q https://github.com/TheLastBen/fast-stable-diffusion/raw/main/precompiled/V100/xformers-0.0.13.dev0-py3-none-any.whl
  
  elif (gpu=='A100'):
    # %pip install -q https://github.com/TheLastBen/fast-stable-diffusion/raw/main/precompiled/A100/xformers-0.0.13.dev0-py3-none-any.whl

#painthua - inpaint outpaint module
# if(outpaint_inpaint_module):
#   !pip install flask
#   %cd /content
#   !git clone https://github.com/daswer123/painthua-flask
#   %cd /content/painthua-flask
#   !nohup python app_colab.py > painthau.log 2>&1 & 


#Mini-scrtipt to change one line in code
def replace_line(file_name, line_num, text):
    lines = open(file_name, 'r').readlines()
    lines[line_num] = text
    out = open(file_name, 'w')
    out.writelines(lines)
    out.close()

def replace_line_in_file(file_name, line_to_search, text_to_replace):
    with open(file_name, 'r') as file:
        # read a list of lines into data
        data = file.readlines()

    for line in data:
        # if the line contains the string we're looking for,
        # write the line to the output file
        if line_to_search in line:
            replace_line(file_name, data.index(line), text_to_replace)

# !pip install flask
# %cd /content
# !git clone https://github.com/daswer123/painthua-flask

# %cd /content/stable-diffusion-webui
# Out:
# Python 3.9.1
# --2022-12-22 10:06:07--  https://repo.anaconda.com/miniconda/Miniconda3-py39_4.9.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61451533 (59M) [application/x-sh]
# Saving to: ‘mini.sh’
#
# mini.sh             100%[===================>]  58.60M   120MB/s    in 0.5s
#
# 2022-12-22 10:06:08 (120 MB/s) - ‘mini.sh’ saved [61451533/61451533]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# failed with initial frozen solve. Retrying with flexible solve.
# /
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# UnsatisfiableError: The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package libstdcxx-ng conflicts for:
# defusedxml -> python -> libstdcxx-ng[version='>=7.3.0']
# executing -> python[version='>=2.7'] -> libstdcxx-ng[version='>=7.3.0']
# yarl -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# attrs -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# ipython -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# debugpy -> libstdcxx-ng[version='>=7.5.0']
# notebook-shim -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# stack_data -> python[version='>=3.5'] -> libstdcxx-ng[version='>=7.3.0']
# conda==4.9.2=py39h06a4308_0 -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# pyopenssl==20.0.0=pyhd3eb1b0_1 -> python -> libstdcxx-ng[version='>=7.3.0']
# pyu2f -> python[version='>=2.7'] -> libstdcxx-ng[version='>=7.3.0']
# pandas -> numpy[version='>=1.19.5,<2.0a0'] -> libstdcxx-ng[version='>=10.3.0|>=7.3.0']
# numpy -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# ruamel_yaml==0.15.80=py39h27cfd23_0 -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# argon2-cffi-bindings -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# jupyter_server -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=11.2.0|>=7.3.0']
# packaging -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# pycparser==2.20=py_2 -> python -> libstdcxx-ng[version='>=7.3.0']
# urllib3==1.25.11=py_0 -> python[version='<4.0'] -> libstdcxx-ng[version='>=7.3.0']
# ply -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# send2trash -> python -> libstdcxx-ng[version='>=7.3.0']
# pure_eval -> python[version='>=3.5'] -> libstdcxx-ng[version='>=7.3.0']
# tinycss2 -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# libtiff -> libstdcxx-ng[version='>=11.2.0']
# libtiff -> lerc[version='>=3.0,<4.0a0'] -> libstdcxx-ng[version='>=7.5.0']
# nbconvert -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# libedit==3.1.20191231=h14c3975_1 -> ncurses[version='>=6.2,<7.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# charset-normalizer -> python[version='>=3.6'] -> libstdcxx-ng[version='>=7.3.0']
# pandas -> libstdcxx-ng[version='>=9.3.0']
# jupyterlab_server -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# six==1.15.0=py39h06a4308_0 -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# pycosat==0.6.3=py39h27cfd23_0 -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# libxslt -> icu[version='>=58.2,<59.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# libwebp -> libtiff[version='>=4.1.0,<5.0a0'] -> libstdcxx-ng[version='>=11.2.0']
# google-colab -> pandas -> libstdcxx-ng[version='>=7.3.0|>=9.3.0']
# rsa -> python[version='>=3.6'] -> libstdcxx-ng[version='>=7.3.0']
# dbus -> expat[version='>=2.2.10,<3.0a0'] -> libstdcxx-ng[version='>=11.2.0|>=7.5.0']
# markupsafe -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# lxml -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# setuptools==51.0.0=py39h06a4308_2 -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# matplotlib-inline -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# pysocks==1.7.1=py39h06a4308_0 -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# brotlipy==0.7.0=py39h27cfd23_1003 -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# python==3.9.1=hdb3f193_2 -> libstdcxx-ng[version='>=7.3.0']
# gstreamer -> glib[version='>=2.66.1,<3.0a0'] -> libstdcxx-ng[version='>=7.5.0']
# aiosignal -> python[version='>=3.7'] -> libstdcxx-ng[version='>=7.3.0']
# ipython_genutils -> python -> libstdcxx-ng[version='>=7.3.0']
# pandocfilters -> python[version='!=3.0,!=3.1,!=3.2,!=3.3'] -> libstdcxx-ng[version='>=7.3.0']
# jinja2 -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# portpicker -> python[version='>=3.6'] -> libstdcxx-ng[version='>=7.3.0']
# toolz -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# typing_extensions -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# babel -> python[version='>=3.6'] -> libstdcxx-ng[version='>=7.3.0']
# libffi==3.3=he6710b0_2 -> libstdcxx-ng[version='>=7.3.0']
# toml -> python[version='>=2.7'] -> libstdcxx-ng[version='>=7.3.0']
# qtpy -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# async-timeout -> python[version='>=3.6'] -> libstdcxx-ng[version='>=7.3.0']
# lerc -> libstdcxx-ng[version='>=7.5.0']
# jedi -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# zstd -> libstdcxx-ng[version='>=7.5.0']
# pyasn1 -> python -> libstdcxx-ng[version='>=7.3.0']
# frozenlist -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# websocket-client -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# libclang -> libstdcxx-ng[version='>=7.3.0']
# qtconsole -> pyqt -> libstdcxx-ng[version='>=11.2.0|>=7.3.0']
# pcre -> libstdcxx-ng[version='>=7.5.0']
# sip -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# nspr -> libstdcxx-ng[version='>=7.5.0']
# google-auth -> python[version='>=3.6'] -> libstdcxx-ng[version='>=7.3.0']
# pyzmq -> libstdcxx-ng[version='>=11.2.0']
# zeromq -> libstdcxx-ng[version='>=7.3.0']
# nbclassic -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=11.2.0|>=7.3.0']
# lz4-c -> libstdcxx-ng[version='>=11.2.0']
# pygments -> python[version='>=3.5'] -> libstdcxx-ng[version='>=7.3.0']
# qt-main -> libstdcxx-ng[version='>=11.2.0']
# expat -> libstdcxx-ng[version='>=11.2.0']
# certifi==2020.12.5=py39h06a4308_0 -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# pytz -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# zstd -> lz4-c[version='>=1.9.3,<1.10.0a0'] -> libstdcxx-ng[version='>=11.2.0']
# pyqt -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# qtwebkit -> libstdcxx-ng[version='>=11.2.0']
# pyqt5-sip -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# pyzmq -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# ipywidgets -> python -> libstdcxx-ng[version='>=7.3.0']
# pyqt -> libstdcxx-ng[version='>=11.2.0']
# wheel==0.36.1=pyhd3eb1b0_0 -> python -> libstdcxx-ng[version='>=7.3.0']
# idna==2.10=py_0 -> python -> libstdcxx-ng[version='>=7.3.0']
# pyqt5-sip -> libstdcxx-ng[version='>=11.2.0']
# chardet==3.0.4=py39h06a4308_1003 -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# jupyter_console -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# python_abi -> python=3.9 -> libstdcxx-ng[version='>=7.3.0']
# nest-asyncio -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# jupyterlab_widgets -> python[version='>=3.6'] -> libstdcxx-ng[version='>=7.3.0']
# requests==2.25.0=pyhd3eb1b0_0 -> python -> libstdcxx-ng[version='>=7.3.0']
# nss -> libstdcxx-ng[version='>=7.5.0']
# conda-package-handling==1.7.2=py39h27cfd23_1 -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# gst-plugins-base -> libstdcxx-ng[version='>=7.3.0']
# readline==8.0=h7b6447c_0 -> ncurses[version='>=6.1,<7.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# glib -> libffi[version='>=3.3'] -> libstdcxx-ng[version='>=7.3.0']
# terminado -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# jupyter -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# ncurses==6.2=he6710b0_1 -> libstdcxx-ng[version='>=7.3.0']
# multidict -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# ruamel.yaml.clib -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# backcall -> python -> libstdcxx-ng[version='>=7.3.0']
# webencodings -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# bleach -> python[version='>=3.6'] -> libstdcxx-ng[version='>=7.3.0']
# widgetsnbextension -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# cffi==1.14.4=py39h261ae71_0 -> libffi[version='>=3.3,<3.4.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# anyio -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# beautifulsoup4 -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# tornado -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# asttokens -> python[version='>=3.5'] -> libstdcxx-ng[version='>=7.3.0']
# cryptography==3.3.1=py39h3c74f83_0 -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# pyasn1-modules -> python -> libstdcxx-ng[version='>=7.3.0']
# decorator -> python[version='>=3.5'] -> libstdcxx-ng[version='>=7.3.0']
# python-dateutil -> python -> libstdcxx-ng[version='>=7.3.0']
# ptyprocess -> python -> libstdcxx-ng[version='>=7.3.0']
# glib -> libstdcxx-ng[version='>=7.5.0']
# pip==20.3.1=py39h06a4308_0 -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# notebook -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=11.2.0|>=7.3.0']
# cachetools -> python[version='>=3.7'] -> libstdcxx-ng[version='>=7.3.0']
# libllvm10 -> libstdcxx-ng[version='>=7.3.0']
# psutil -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# zipp -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# nbclient -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# prometheus_client -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# mistune -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# libxml2 -> icu[version='>=58.2,<59.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# aiohttp -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# libstdcxx-ng==9.1.0=hdf63c60_0
# sniffio -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# qt-webengine -> libstdcxx-ng[version='>=11.2.0']
# pickleshare -> python[version='>=3'] -> libstdcxx-ng[version='>=7.3.0']
# pyrsistent -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# traitlets -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# icu -> libstdcxx-ng[version='>=7.3.0']
# numpy -> libstdcxx-ng[version='>=10.3.0']
# jsonschema -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# prompt-toolkit -> python -> libstdcxx-ng[version='>=7.3.0']
# flit-core -> python[version='>=3.6'] -> libstdcxx-ng[version='>=7.3.0']
# pexpect -> python -> libstdcxx-ng[version='>=7.3.0']
# parso -> python[version='>=3.6'] -> libstdcxx-ng[version='>=7.3.0']
# qt-webengine -> glib[version='>=2.69.1,<3.0a0'] -> libstdcxx-ng[version='>=7.5.0']
# soupsieve -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# sip -> libstdcxx-ng[version='>=11.2.0']
# json5 -> python -> libstdcxx-ng[version='>=7.3.0']
# importlib-metadata -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# pluggy -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# jupyterlab_pygments -> python -> libstdcxx-ng[version='>=7.3.0']
# argon2-cffi -> python[version='>=3.6'] -> libstdcxx-ng[version='>=7.3.0']
# qt-main -> glib[version='>=2.69.1,<3.0a0'] -> libstdcxx-ng[version='>=7.3.0|>=7.5.0']
# fontconfig -> expat[version='>=2.4.9,<3.0a0'] -> libstdcxx-ng[version='>=11.2.0']
# jupyter_client -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=11.2.0|>=7.3.0']
# nbformat -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# entrypoints -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# typing-extensions -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# debugpy -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# sqlite==3.33.0=h62c20be_0 -> ncurses[version='>=6.2,<7.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# gst-plugins-base -> glib[version='>=2.66.1,<3.0a0'] -> libstdcxx-ng[version='>=7.5.0']
# jupyter_core -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# wcwidth -> python -> libstdcxx-ng[version='>=7.3.0']
# ruamel.yaml -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# qtwebkit -> glib[version='>=2.69.1,<3.0a0'] -> libstdcxx-ng[version='>=7.3.0|>=7.5.0']
# python-fastjsonschema -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# ipykernel -> debugpy[version='>=1.0.0'] -> libstdcxx-ng[version='>=11.2.0|>=7.3.0|>=7.5.0']
# jupyterlab -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
# tomli -> python[version='>=3.9,<3.10.0a0'] -> libstdcxx-ng[version='>=7.3.0']
#
# Package libtiff conflicts for:
# libtiff
# qtwebkit -> libwebp[version='>=1.2.0,<1.3.0a0'] -> libtiff[version='>=4.1.0,<5.0a0']
# libwebp -> libtiff[version='>=4.1.0,<5.0a0']
#
# Package readline conflicts for:
# jupyterlab_widgets -> python[version='>=3.6'] -> readline[version='>=8.0,<9.0a0']
# cryptography==3.3.1=py39h3c74f83_0 -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# conda-package-handling==1.7.2=py39h27cfd23_1 -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# toml -> python[version='>=2.7'] -> readline[version='>=8.0,<9.0a0']
# qtpy -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# jedi -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# jupyter -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# argon2-cffi -> python[version='>=3.6'] -> readline[version='>=8.0,<9.0a0']
# nbclassic -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# multidict -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# nbconvert -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# pyasn1 -> python -> readline[version='>=8.0,<9.0a0']
# backcall -> python -> readline[version='>=8.0,<9.0a0']
# webencodings -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# bleach -> python[version='>=3.6'] -> readline[version='>=8.0,<9.0a0']
# sip -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# beautifulsoup4 -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# tornado -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# ptyprocess -> python -> readline[version='>=8.0,<9.0a0']
# ruamel.yaml -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# tomli -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# pyqt -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# cachetools -> python[version='>=3.7'] -> readline[version='>=8.0,<9.0a0']
# psutil -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# zipp -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# decorator -> python[version='>=3.5'] -> readline[version='>=8.0,<9.0a0']
# nbclient -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# pyzmq -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# conda==4.9.2=py39h06a4308_0 -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# ipywidgets -> python -> readline[version='>=8.0,<9.0a0']
# pyu2f -> python[version='>=2.7'] -> readline[version='>=8.0,<9.0a0']
# google-colab -> python -> readline[version='>=8.0,<9.0a0']
# pickleshare -> python[version='>=3'] -> readline[version='>=8.0,<9.0a0']
# pyrsistent -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# requests==2.25.0=pyhd3eb1b0_0 -> python -> readline[version='>=8.0,<9.0a0']
# entrypoints -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# aiohttp -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# sniffio -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# qtconsole -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# soupsieve -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# traitlets -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# json5 -> python -> readline[version='>=8.0,<9.0a0']
# ruamel.yaml.clib -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# pexpect -> python -> readline[version='>=8.0,<9.0a0']
# prompt-toolkit -> python -> readline[version='>=8.0,<9.0a0']
# widgetsnbextension -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# typing-extensions -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# pyasn1-modules -> python -> readline[version='>=8.0,<9.0a0']
# defusedxml -> python -> readline[version='>=8.0,<9.0a0']
# urllib3==1.25.11=py_0 -> python[version='<4.0'] -> readline[version='>=8.0,<9.0a0']
# pysocks==1.7.1=py39h06a4308_0 -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# libpq -> readline[version='>=8.0,<9.0a0']
# tinycss2 -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# matplotlib-inline -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# mistune -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# nest-asyncio -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# rsa -> python[version='>=3.6'] -> readline[version='>=8.0,<9.0a0']
# executing -> python[version='>=2.7'] -> readline[version='>=8.0,<9.0a0']
# python==3.9.1=hdb3f193_2 -> readline[version='>=8.0,<9.0a0']
# numpy -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# argon2-cffi-bindings -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# readline==8.0=h7b6447c_0
# packaging -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# jsonschema -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# ipython_genutils -> python -> readline[version='>=8.0,<9.0a0']
# pandocfilters -> python[version='!=3.0,!=3.1,!=3.2,!=3.3'] -> readline[version='>=8.0,<9.0a0']
# notebook -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# jupyterlab_pygments -> python -> readline[version='>=8.0,<9.0a0']
# asttokens -> python[version='>=3.5'] -> readline[version='>=8.0,<9.0a0']
# pycparser==2.20=py_2 -> python -> readline[version='>=8.0,<9.0a0']
# idna==2.10=py_0 -> python -> readline[version='>=8.0,<9.0a0']
# pip==20.3.1=py39h06a4308_0 -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# debugpy -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# jupyter_core -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# terminado -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# qt-main -> libpq[version='>=12.9,<13.0a0'] -> readline[version='>=8.0,<9.0a0']
# wcwidth -> python -> readline[version='>=8.0,<9.0a0']
# pycosat==0.6.3=py39h27cfd23_0 -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# python-fastjsonschema -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# jupyterlab -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# aiosignal -> python[version='>=3.7'] -> readline[version='>=8.0,<9.0a0']
# ipython -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# jupyterlab_server -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# notebook-shim -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# six==1.15.0=py39h06a4308_0 -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# websocket-client -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# chardet==3.0.4=py39h06a4308_1003 -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# python-dateutil -> python -> readline[version='>=8.0,<9.0a0']
# stack_data -> python[version='>=3.5'] -> readline[version='>=8.0,<9.0a0']
# yarl -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# parso -> python[version='>=3.6'] -> readline[version='>=8.0,<9.0a0']
# ruamel_yaml==0.15.80=py39h27cfd23_0 -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# pyqt5-sip -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# jupyter_client -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# lxml -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# importlib-metadata -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# pluggy -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# prometheus_client -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# pure_eval -> python[version='>=3.5'] -> readline[version='>=8.0,<9.0a0']
# ply -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# jinja2 -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# portpicker -> python[version='>=3.6'] -> readline[version='>=8.0,<9.0a0']
# google-auth -> python[version='>=3.6'] -> readline[version='>=8.0,<9.0a0']
# nss -> sqlite[version='>=3.37.0,<4.0a0'] -> readline[version='>=8.0,<9.0a0']
# async-timeout -> python[version='>=3.6'] -> readline[version='>=8.0,<9.0a0']
# toolz -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# typing_extensions -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# attrs -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# babel -> python[version='>=3.6'] -> readline[version='>=8.0,<9.0a0']
# frozenlist -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# qtwebkit -> sqlite[version='>=3.38.5,<4.0a0'] -> readline[version='>=8.0,<9.0a0']
# pandas -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# jupyter_server -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# anyio -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# cffi==1.14.4=py39h261ae71_0 -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# nbformat -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# wheel==0.36.1=pyhd3eb1b0_0 -> python -> readline[version='>=8.0,<9.0a0']
# markupsafe -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# setuptools==51.0.0=py39h06a4308_2 -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# pygments -> python[version='>=3.5'] -> readline[version='>=8.0,<9.0a0']
# flit-core -> python[version='>=3.6'] -> readline[version='>=8.0,<9.0a0']
# brotlipy==0.7.0=py39h27cfd23_1003 -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# pytz -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# pyopenssl==20.0.0=pyhd3eb1b0_1 -> python -> readline[version='>=8.0,<9.0a0']
# ipykernel -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# charset-normalizer -> python[version='>=3.6'] -> readline[version='>=8.0,<9.0a0']
# send2trash -> python -> readline[version='>=8.0,<9.0a0']
# certifi==2020.12.5=py39h06a4308_0 -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# jupyter_console -> python[version='>=3.9,<3.10.0a0'] -> readline[version='>=8.0,<9.0a0']
# python_abi -> python=3.9 -> readline[version='>=8.0,<9.0a0']
#
# Package python conflicts for:
# conda-package-handling==1.7.2=py39h27cfd23_1 -> python[version='>=3.9,<3.10.0a0']
# numpy -> python[version='>=3.9,<3.10.0a0']
# webencodings -> python[version='>=3.9,<3.10.0a0']
# toml -> python[version='>=2.7']
# portpicker -> psutil -> python[version='>=3.9,<3.10.0a0']
# attrs -> python[version='>=3.9,<3.10.0a0']
# pyasn1-modules -> python
# json5 -> python
# nbclassic -> python[version='>=3.9,<3.10.0a0']
# conda==4.9.2=py39h06a4308_0 -> pyopenssl[version='>=16.2.0'] -> python
# qtconsole -> python[version='>=3.9,<3.10.0a0']
# pyu2f -> python[version='>=2.7']
# backcall -> python
# notebook -> argon2-cffi -> python[version='>=3.6']
# packaging -> python[version='>=3.9,<3.10.0a0']
# pure_eval -> python[version='>=3.5']
# ipython -> backcall -> python[version='>=3|>=3.5']
# nbclassic -> argon2-cffi -> python[version='>=3.6']
# python-dateutil -> six[version='>=1.5'] -> python[version='>=3.9,<3.10.0a0']
# pandocfilters -> python[version='!=3.0,!=3.1,!=3.2,!=3.3']
# ruamel_yaml==0.15.80=py39h27cfd23_0 -> python[version='>=3.9,<3.10.0a0']
# nbformat -> python[version='>=3.9,<3.10.0a0']
# pyopenssl==20.0.0=pyhd3eb1b0_1 -> python
# pygments -> python[version='>=3.5']
# jupyterlab_pygments -> python
# pip==20.3.1=py39h06a4308_0 -> python[version='>=3.9,<3.10.0a0']
# portpicker -> python[version='>=3.6']
# babel -> pytz[version='>=2015.7'] -> python[version='>=3.9,<3.10.0a0']
# ply -> python[version='>=3.9,<3.10.0a0']
# bleach -> packaging -> python[version='>=3.9,<3.10.0a0']
# setuptools==51.0.0=py39h06a4308_2 -> python[version='>=3.9,<3.10.0a0']
# python-fastjsonschema -> python[version='>=3.9,<3.10.0a0']
# typing-extensions -> python[version='>=3.9,<3.10.0a0']
# jupyter_client -> python-dateutil[version='>=2.8.2'] -> python
# toolz -> python[version='>=3.9,<3.10.0a0']
# pyopenssl==20.0.0=pyhd3eb1b0_1 -> cryptography[version='>=2.8'] -> python[version='>=3.9,<3.10.0a0']
# yarl -> python[version='>=3.9,<3.10.0a0']
# setuptools==51.0.0=py39h06a4308_2 -> certifi[version='>=2016.9.26'] -> python[version='>=3.7']
# traitlets -> python[version='>=3.9,<3.10.0a0']
# anyio -> idna[version='>=2.8'] -> python
# cryptography==3.3.1=py39h3c74f83_0 -> python[version='>=3.9,<3.10.0a0']
# ipywidgets -> python
# aiosignal -> python[version='>=3.7']
# chardet==3.0.4=py39h06a4308_1003 -> python[version='>=3.9,<3.10.0a0']
# asttokens -> python[version='>=3.5']
# jedi -> python[version='>=3.9,<3.10.0a0']
# aiohttp -> aiosignal[version='>=1.1.2'] -> python[version='3.9.*|>=3.6|>=3.7']
# jupyterlab_pygments -> pygments[version='>=2.4.1,<3'] -> python[version='>=3.5']
# pytz -> python[version='>=3.9,<3.10.0a0']
# brotlipy==0.7.0=py39h27cfd23_1003 -> python[version='>=3.9,<3.10.0a0']
# jupyter_console -> python[version='>=3.9,<3.10.0a0']
# urllib3==1.25.11=py_0 -> brotlipy[version='>=0.6.0'] -> python[version='>=3.7|>=3.9,<3.10.0a0']
# urllib3==1.25.11=py_0 -> python[version='<4.0']
# soupsieve -> python[version='>=3.9,<3.10.0a0']
# ptyprocess -> python
# multidict -> python[version='>=3.9,<3.10.0a0']
# defusedxml -> python
# babel -> python[version='>=3.6']
# pip==20.3.1=py39h06a4308_0 -> wheel -> python
# charset-normalizer -> python[version='>=3.6']
# terminado -> ptyprocess -> python
# pyqt5-sip -> toml -> python[version='>=2.7']
# pickleshare -> python[version='>=3']
# parso -> python[version='>=3.6']
# jupyter_core -> python[version='>=3.9,<3.10.0a0']
# mistune -> python[version='>=3.9,<3.10.0a0']
# jupyterlab_server -> python[version='>=3.9,<3.10.0a0']
# jedi -> parso[version='>=0.8.0,<0.9.0'] -> python[version='>=3.6']
# lxml -> python[version='>=3.9,<3.10.0a0']
# jinja2 -> python[version='>=3.9,<3.10.0a0']
# pycosat==0.6.3=py39h27cfd23_0 -> python[version='>=3.9,<3.10.0a0']
# six==1.15.0=py39h06a4308_0 -> python[version='>=3.9,<3.10.0a0']
# notebook -> python[version='>=3.9,<3.10.0a0']
# frozenlist -> python[version='>=3.9,<3.10.0a0']
# argon2-cffi -> argon2-cffi-bindings -> python[version='>=3.9,<3.10.0a0']
# google-auth -> python[version='>=3.6']
# tornado -> python[version='>=3.9,<3.10.0a0']
# pyu2f -> six -> python[version='>=3.9,<3.10.0a0']
# jupyter_client -> python[version='>=3.9,<3.10.0a0']
# sip -> python[version='>=3.9,<3.10.0a0']
# jupyterlab_server -> babel -> python[version='>=3.6']
# prompt_toolkit -> prompt-toolkit[version='>=3.0.20,<3.0.21.0a0'] -> python
# matplotlib-inline -> python[version='>=3.9,<3.10.0a0']
# google-auth -> aiohttp[version='>=3.6.2,<4.0.0dev'] -> python[version='>=2.7|>=3.7|>=3.9,<3.10.0a0']
# ipython_genutils -> python
# terminado -> python[version='>=3.9,<3.10.0a0']
# pandas -> python-dateutil[version='>=2.7.3'] -> python=3.9
# async-timeout -> python[version='>=3.6']
# tomli -> python[version='>=3.9,<3.10.0a0']
# aiohttp -> python[version='>=3.9,<3.10.0a0']
# anyio -> python[version='>=3.9,<3.10.0a0']
# rsa -> python[version='>=3.6']
# stack_data -> executing -> python[version='>=2.7']
# ipython -> python[version='>=3.9,<3.10.0a0']
# jupyter_server -> python[version='>=3.9,<3.10.0a0']
# send2trash -> python
# aiosignal -> frozenlist[version='>=1.1.0'] -> python[version='>=3.9,<3.10.0a0']
# cffi==1.14.4=py39h261ae71_0 -> pycparser -> python
# nbclient -> python[version='>=3.9,<3.10.0a0']
# pyasn1 -> python
# argon2-cffi-bindings -> python[version='>=3.9,<3.10.0a0']
# nbconvert -> bleach -> python[version='!=3.0,!=3.1,!=3.2,!=3.3|>=3.6|>=3.5']
# python==3.9.1=hdb3f193_2
# pexpect -> python
# websocket-client -> python[version='>=3.9,<3.10.0a0']
# ipykernel -> python[version='>=3.9,<3.10.0a0']
# pyqt5-sip -> python[version='>=3.9,<3.10.0a0']
# jupyter_console -> pygments -> python[version='>=3.5']
# asttokens -> six -> python[version='>=3.9,<3.10.0a0']
# sniffio -> python[version='>=3.9,<3.10.0a0']
# pyrsistent -> python[version='>=3.9,<3.10.0a0']
# jupyter -> ipywidgets -> python
# google-colab -> google-auth -> python[version='>=3.6|>=3.9,<3.10.0a0']
# flit-core -> python[version='>=3.6']
# widgetsnbextension -> python[version='>=3.9,<3.10.0a0']
# nest-asyncio -> python[version='>=3.9,<3.10.0a0']
# pysocks==1.7.1=py39h06a4308_0 -> python[version='>=3.9,<3.10.0a0']
# decorator -> python[version='>=3.5']
# entrypoints -> python[version='>=3.9,<3.10.0a0']
# markupsafe -> python[version='>=3.9,<3.10.0a0']
# requests==2.25.0=pyhd3eb1b0_0 -> certifi[version='>=2017.4.17'] -> python[version='<4.0|>=3.7|>=3.9,<3.10.0a0']
# wheel==0.36.1=pyhd3eb1b0_0 -> python
# async-timeout -> typing-extensions[version='>=3.6.5'] -> python[version='>=3.9,<3.10.0a0']
# python-dateutil -> python
# argon2-cffi -> python[version='>=3.6']
# wcwidth -> python
# beautifulsoup4 -> python[version='>=3.9,<3.10.0a0']
# executing -> python[version='>=2.7']
# ruamel.yaml.clib -> python[version='>=3.9,<3.10.0a0']
# tinycss2 -> python[version='>=3.9,<3.10.0a0']
# jupyter_server -> argon2-cffi -> python[version='>=3.6']
# rsa -> pyasn1[version='>=0.1.3'] -> python
# debugpy -> python[version='>=3.9,<3.10.0a0']
# ruamel.yaml -> python[version='>=3.9,<3.10.0a0']
# qtconsole -> ipython_genutils -> python[version='>=3.5']
# sip -> toml -> python[version='>=2.7']
# conda-package-handling==1.7.2=py39h27cfd23_1 -> tqdm -> python[version='>=2.7']
# jupyterlab_widgets -> python[version='>=3.6']
# pyzmq -> python[version='>=3.9,<3.10.0a0']
# ipywidgets -> ipykernel[version='>=4.5.1'] -> python[version='>=3.6|>=3.9,<3.10.0a0']
# pyqt -> python[version='>=3.9,<3.10.0a0']
# jsonschema -> python[version='>=3.9,<3.10.0a0']
# typing_extensions -> python[version='>=3.9,<3.10.0a0']
# nbconvert -> python[version='>=3.9,<3.10.0a0']
# bleach -> python[version='>=3.6']
# python_abi -> python=3.9
# stack_data -> python[version='>=3.5']
# google-colab -> python
# notebook-shim -> python[version='>=3.9,<3.10.0a0']
# prompt-toolkit -> python
# multidict -> python_abi=3.9[build=*_cp39] -> python=3.9
# cffi==1.14.4=py39h261ae71_0 -> python[version='>=3.9,<3.10.0a0']
# pluggy -> python[version='>=3.9,<3.10.0a0']
# qtpy -> python[version='>=3.9,<3.10.0a0']
# pycparser==2.20=py_2 -> python
# certifi==2020.12.5=py39h06a4308_0 -> python[version='>=3.9,<3.10.0a0']
# yarl -> idna[version='>=2.0'] -> python=3.9
# conda==4.9.2=py39h06a4308_0 -> python[version='>=3.9,<3.10.0a0']
# zipp -> python[version='>=3.9,<3.10.0a0']
# typing_extensions -> flit-core[version='>=3.6,<4'] -> python[version='>=3.6']
# numpy -> python_abi=3.9[build=*_cp39] -> python=3.9
# pandas -> python[version='>=3.9,<3.10.0a0']
# jupyterlab -> python[version='>=3.9,<3.10.0a0']
# requests==2.25.0=pyhd3eb1b0_0 -> python
# importlib-metadata -> python[version='>=3.9,<3.10.0a0']
# psutil -> python[version='>=3.9,<3.10.0a0']
# prometheus_client -> python[version='>=3.9,<3.10.0a0']
# jupyter -> python[version='>=3.9,<3.10.0a0']
# cachetools -> python[version='>=3.7']
# idna==2.10=py_0 -> python
#
# Package libxml2 conflicts for:
# libxslt -> libxml2[version='>=2.9.14,<2.10.0a0']
# qtwebkit -> libxml2[version='>=2.9.14,<2.10.0a0']
# pyqt -> qt-main=5.15 -> libxml2[version='>=2.9.14,<2.10.0a0']
# lxml -> libxml2[version='>=2.9.14,<2.10.0a0|>=2.9.2,!=2.9.11,!=2.9.12']
# qt-main -> libxkbcommon[version='>=1.0.1,<2.0a0'] -> libxml2[version='>=2.9.12,<2.10.0a0']
# qt-webengine -> libxkbcommon[version='>=1.0.1,<2.0a0'] -> libxml2[version='>=2.9.12,<2.10.0a0']
# libxml2
# qt-main -> libxml2[version='>=2.9.14,<2.10.0a0']
# nbconvert -> lxml -> libxml2[version='>=2.9.14,<2.10.0a0|>=2.9.2,!=2.9.11,!=2.9.12']
# fontconfig -> libxml2[version='>=2.9.14,<2.10.0a0']
# libxkbcommon -> libxml2[version='>=2.9.12,<2.10.0a0']
# qt-webengine -> libxml2[version='>=2.9.14,<2.10.0a0']
#
# Package jsonschema conflicts for:
# nbconvert -> nbformat[version='>=5.1'] -> jsonschema[version='>=2.6']
# ipywidgets -> nbformat[version='>=4.2.0'] -> jsonschema[version='>=2.6']
# nbclient -> nbformat[version='>=5.0'] -> jsonschema[version='>=2.6']
# notebook -> nbformat -> jsonschema[version='>=2.6']
# jupyterlab -> jupyterlab_server[version='>=2.10,<3'] -> jsonschema[version='>=3.0.1']
# jupyter_server -> nbformat[version='>=5.2.0'] -> jsonschema[version='>=2.6']
# nbformat -> jsonschema[version='>=2.6']
# jupyterlab_server -> jsonschema[version='>=3.0.1']
# jsonschema
# nbclassic -> nbformat -> jsonschema[version='>=2.6']
#
# Package tornado conflicts for:
# jupyter_console -> ipykernel -> tornado[version='>=6.1,<7.0|>=6.2']
# tornado
# ipykernel -> tornado[version='>=6.1,<7.0']
# jupyter_client -> tornado[version='>=6.2']
# widgetsnbextension -> notebook[version='>=4.4.1'] -> tornado[version='>=6.1']
# jupyterlab -> nbclassic -> tornado[version='>=6.1']
# ipywidgets -> ipykernel[version='>=4.5.1'] -> tornado[version='>=6.1,<7.0']
# jupyterlab -> tornado[version='>=6.1.0']
# qtconsole -> ipykernel[version='>=4.1'] -> tornado[version='>=6.1,<7.0|>=6.2']
# google-colab -> ipykernel -> tornado[version='>=6.1|>=6.1,<7.0']
# notebook-shim -> jupyter_server[version='>=1.8,<3'] -> tornado[version='>=6.1.0']
# notebook -> ipykernel -> tornado[version='>=4|>=6.1,<7.0|>=6.2']
# notebook -> tornado[version='>=6.1']
# jupyter_server -> tornado[version='>=6.1.0']
# jupyterlab_server -> jupyter_server[version='>=1.8,<3'] -> tornado[version='>=6.1.0']
# nbclassic -> ipykernel -> tornado[version='>=4|>=6.1,<7.0|>=6.2|>=6.1.0']
# terminado -> tornado[version='>=4']
# nbclassic -> tornado[version='>=6.1']
# nbclient -> jupyter_client[version='>=6.1.5'] -> tornado[version='>=6.2']
# ipykernel -> jupyter_client[version='>=6.1.12'] -> tornado[version='>=6.2']
# jupyter_server -> jupyter_client[version='>=6.1.12'] -> tornado[version='>=4|>=6.2']
# jupyter -> ipykernel -> tornado[version='>=6.1|>=6.1,<7.0|>=6.1.0']
# google-colab -> tornado
#
# Package ld_impl_linux-64 conflicts for:
# json5 -> python -> ld_impl_linux-64
# notebook -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# jupyterlab_pygments -> python -> ld_impl_linux-64
# prompt-toolkit -> python -> ld_impl_linux-64
# typing-extensions -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# nbconvert -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# pyasn1 -> python -> ld_impl_linux-64
# python-fastjsonschema -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# jupyterlab -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# defusedxml -> python -> ld_impl_linux-64
# urllib3==1.25.11=py_0 -> python[version='<4.0'] -> ld_impl_linux-64
# jupyterlab_server -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# notebook-shim -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# wcwidth -> python -> ld_impl_linux-64
# nest-asyncio -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# python-dateutil -> python -> ld_impl_linux-64
# pytz -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# rsa -> python[version='>=3.6'] -> ld_impl_linux-64
# executing -> python[version='>=2.7'] -> ld_impl_linux-64
# pyopenssl==20.0.0=pyhd3eb1b0_1 -> python -> ld_impl_linux-64
# yarl -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# ipykernel -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# python==3.9.1=hdb3f193_2 -> ld_impl_linux-64
# numpy -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# ruamel_yaml==0.15.80=py39h27cfd23_0 -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# argon2-cffi-bindings -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# jupyter_client -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# packaging -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# lxml -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# ipywidgets -> python -> ld_impl_linux-64
# send2trash -> python -> ld_impl_linux-64
# certifi==2020.12.5=py39h06a4308_0 -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# pandocfilters -> python[version='!=3.0,!=3.1,!=3.2,!=3.3'] -> ld_impl_linux-64
# pure_eval -> python[version='>=3.5'] -> ld_impl_linux-64
# tinycss2 -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# asttokens -> python[version='>=3.5'] -> ld_impl_linux-64
# toml -> python[version='>=2.7'] -> ld_impl_linux-64
# pycparser==2.20=py_2 -> python -> ld_impl_linux-64
# aiohttp -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# idna==2.10=py_0 -> python -> ld_impl_linux-64
# qtconsole -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# pip==20.3.1=py39h06a4308_0 -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# toolz -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# typing_extensions -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# babel -> python[version='>=3.6'] -> ld_impl_linux-64
# jupyter_core -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# terminado -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# backcall -> python -> ld_impl_linux-64
# pycosat==0.6.3=py39h27cfd23_0 -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# jupyter_server -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# pyasn1-modules -> python -> ld_impl_linux-64
# cffi==1.14.4=py39h261ae71_0 -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# six==1.15.0=py39h06a4308_0 -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# markupsafe -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# websocket-client -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# setuptools==51.0.0=py39h06a4308_2 -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# pysocks==1.7.1=py39h06a4308_0 -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# psutil -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# brotlipy==0.7.0=py39h27cfd23_1003 -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# pyqt5-sip -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# pluggy -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# matplotlib-inline -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# jinja2 -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# sniffio -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# parso -> python[version='>=3.6'] -> ld_impl_linux-64
# async-timeout -> python[version='>=3.6'] -> ld_impl_linux-64
# jedi -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# importlib-metadata -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# ruamel.yaml.clib -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# attrs -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# argon2-cffi -> python[version='>=3.6'] -> ld_impl_linux-64
# frozenlist -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# widgetsnbextension -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# pandas -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# qtpy -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# anyio -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# debugpy -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# sip -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# google-auth -> python[version='>=3.6'] -> ld_impl_linux-64
# wheel==0.36.1=pyhd3eb1b0_0 -> python -> ld_impl_linux-64
# ruamel.yaml -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# pygments -> python[version='>=3.5'] -> ld_impl_linux-64
# aiosignal -> python[version='>=3.7'] -> ld_impl_linux-64
# portpicker -> python[version='>=3.6'] -> ld_impl_linux-64
# pyzmq -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# conda==4.9.2=py39h06a4308_0 -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# nbformat -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# pyu2f -> python[version='>=2.7'] -> ld_impl_linux-64
# chardet==3.0.4=py39h06a4308_1003 -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# jupyter_console -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# python_abi -> python=3.9 -> ld_impl_linux-64
# jupyterlab_widgets -> python[version='>=3.6'] -> ld_impl_linux-64
# cryptography==3.3.1=py39h3c74f83_0 -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# requests==2.25.0=pyhd3eb1b0_0 -> python -> ld_impl_linux-64
# flit-core -> python[version='>=3.6'] -> ld_impl_linux-64
# conda-package-handling==1.7.2=py39h27cfd23_1 -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# ipython -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# jupyter -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# traitlets -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# nbclassic -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# multidict -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# charset-normalizer -> python[version='>=3.6'] -> ld_impl_linux-64
# webencodings -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# bleach -> python[version='>=3.6'] -> ld_impl_linux-64
# pexpect -> python -> ld_impl_linux-64
# beautifulsoup4 -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# tornado -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# ptyprocess -> python -> ld_impl_linux-64
# tomli -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# pyqt -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# cachetools -> python[version='>=3.7'] -> ld_impl_linux-64
# zipp -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# decorator -> python[version='>=3.5'] -> ld_impl_linux-64
# nbclient -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# stack_data -> python[version='>=3.5'] -> ld_impl_linux-64
# mistune -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# google-colab -> python -> ld_impl_linux-64
# pickleshare -> python[version='>=3'] -> ld_impl_linux-64
# pyrsistent -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# prometheus_client -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# entrypoints -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# ld_impl_linux-64==2.33.1=h53a641e_7
# ply -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# jsonschema -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
# ipython_genutils -> python -> ld_impl_linux-64
# soupsieve -> python[version='>=3.9,<3.10.0a0'] -> ld_impl_linux-64
#
# Package _libgcc_mutex conflicts for:
# libevent -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# libwebp -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# libedit==3.1.20191231=h14c3975_1 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# libdeflate -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# _libgcc_mutex==0.1=main
# expat -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# tornado -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# pandas -> libgcc-ng[version='>=9.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# python==3.9.1=hdb3f193_2 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# lz4-c -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# nss -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# libwebp-base -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# brotlipy==0.7.0=py39h27cfd23_1003 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# pyqt5-sip -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# libgomp -> _libgcc_mutex==0.1=main
# libuuid -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# libffi==3.3=he6710b0_2 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# pcre -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# glib -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# libxkbcommon -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# icu -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# pyqt -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# debugpy -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# libtiff -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# multidict -> libgcc-ng[version='>=10.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# ruamel.yaml.clib -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# freetype -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# openssl==1.1.1i=h27cfd23_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# libclang -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# qt-webengine -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# libpq -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# aiohttp -> libgcc-ng[version='>=10.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# libxslt -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# ncurses==6.2=he6710b0_1 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# cffi==1.14.4=py39h261ae71_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# xz==5.2.5=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# dbus -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# nspr -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# frozenlist -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# cryptography==3.3.1=py39h3c74f83_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# zeromq -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# zlib==1.2.11=h7b6447c_3 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# qtwebkit -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# markupsafe -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# gst-plugins-base -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# _openmp_mutex -> _libgcc_mutex==0.1=main
# libxcb -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# tk==8.6.10=hbc83047_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# fontconfig -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# readline==8.0=h7b6447c_0 -> libgcc-ng[version='>=7.3.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# argon2-cffi-bindings -> libgcc-ng[version='>=7.5.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# lxml -> libgcc-ng[version='>=11.2.0'] -> _libgcc_mutex[version='*|0.1',build=main]
# ...
#   certifi            conda-forge/noarch::certifi-2022.12.7~ --> pkgs/main/linux-64::certifi-2022.12.7-py39h06a4308_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - google-colab
#
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2022.10.11~ --> conda-forge::ca-certificates-2022.12.7-ha878542_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi            pkgs/main/linux-64::certifi-2022.12.7~ --> conda-forge/noarch::certifi-2022.12.7-pyhd8ed1ab_0
#   conda              pkgs/main::conda-22.11.1-py39h06a4308~ --> conda-forge::conda-22.11.1-py39hf3d152e_1
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installed kernelspec py39 in /root/.local/share/jupyter/kernels/py39
# Python 3.9.1
# /content
# NVIDIA-SMI has failed because it couldn't communicate with the NVIDIA driver. Make sure that the latest NVIDIA driver is installed and running.
#
# humor-sans  liberation
# /tools/node/bin/lt -> /tools/node/lib/node_modules/localtunnel/bin/lt.js
# + localtunnel@2.0.2
# updated 1 package in 1.147s
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.9/site-packages (2.11.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/site-packages (from tensorflow) (2.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/site-packages (from tensorflow) (22.12.6)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/site-packages (from tensorflow) (0.29.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.9/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/site-packages (from tensorflow) (22.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.9/site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/site-packages (from tensorflow) (4.4.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.9/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/site-packages (from tensorflow) (1.3.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.9/site-packages (from tensorflow) (1.22.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/site-packages (from tensorflow) (51.0.0.post20201207)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.9/site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.9/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/site-packages (from tensorflow) (1.51.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.36.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.9/site-packages (from tensorflow) (1.22.3)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.9/site-packages (from tensorflow) (1.22.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.4.6)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/site-packages (from tensorflow) (1.51.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.36.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.25.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (1.8.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/site-packages (from tensorflow) (51.0.0.post20201207)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.2.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.9/site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.9/site-packages (from tensorflow) (1.22.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.15.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (3.4.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/site-packages (from tensorflow) (1.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.2.7)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow) (3.2.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow) (2.25.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow) (0.4.8)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow) (2.1.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_io in /usr/local/lib/python3.9/site-packages (0.29.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.29.0 in /usr/local/lib/python3.9/site-packages (from tensorflow_io) (0.29.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.9/site-packages (4.6.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/site-packages (from gdown) (4.11.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/site-packages (from gdown) (3.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/site-packages (from gdown) (4.54.1)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.9/site-packages (from gdown) (2.25.0)
# Requirement already satisfied: six in /usr/local/lib/python3.9/site-packages (from gdown) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/site-packages (from beautifulsoup4->gdown) (2.3.2.post1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests[socks]->gdown) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests[socks]->gdown) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.9/site-packages (from requests[socks]->gdown) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.9/site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests[socks]->gdown) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests[socks]->gdown) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.9/site-packages (from requests[socks]->gdown) (3.0.4)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/KichangKim/DeepDanbooru.git@edf73df4cdaeea2cf00e9ac08bd8a9026b7a7b26
#   Cloning https://github.com/KichangKim/DeepDanbooru.git (to revision edf73df4cdaeea2cf00e9ac08bd8a9026b7a7b26) to /tmp/pip-req-build-mh4uh9gu
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.9/site-packages (from deepdanbooru==1.0.0) (8.1.3)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.9/site-packages (from deepdanbooru==1.0.0) (1.22.3)
# Requirement already satisfied: scikit-image>=0.15.0 in /usr/local/lib/python3.9/site-packages (from deepdanbooru==1.0.0) (0.19.3)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.9/site-packages (from deepdanbooru==1.0.0) (2.25.0)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.9/site-packages (from deepdanbooru==1.0.0) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.9/site-packages (from requests>=2.22.0->deepdanbooru==1.0.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests>=2.22.0->deepdanbooru==1.0.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests>=2.22.0->deepdanbooru==1.0.0) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests>=2.22.0->deepdanbooru==1.0.0) (1.25.11)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.9/site-packages (from scikit-image>=0.15.0->deepdanbooru==1.0.0) (9.3.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/site-packages (from scikit-image>=0.15.0->deepdanbooru==1.0.0) (22.0)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.9/site-packages (from deepdanbooru==1.0.0) (1.22.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/site-packages (from scikit-image>=0.15.0->deepdanbooru==1.0.0) (2022.10.10)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.9/site-packages (from scikit-image>=0.15.0->deepdanbooru==1.0.0) (2.23.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.9/site-packages (from scikit-image>=0.15.0->deepdanbooru==1.0.0) (1.9.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.9/site-packages (from scikit-image>=0.15.0->deepdanbooru==1.0.0) (1.4.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.9/site-packages (from scikit-image>=0.15.0->deepdanbooru==1.0.0) (2.8.8)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.9/site-packages (from deepdanbooru==1.0.0) (1.22.3)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.9/site-packages (from scikit-image>=0.15.0->deepdanbooru==1.0.0) (9.3.0)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.9/site-packages (from deepdanbooru==1.0.0) (1.22.3)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.9/site-packages (from deepdanbooru==1.0.0) (1.22.3)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.9/site-packages (from deepdanbooru==1.0.0) (1.22.3)
# fatal: destination path 'stable-diffusion-webui' already exists and is not an empty directory.
# /content/stable-diffusion-webui
# /content/stable-diffusion-webui
# Downloading...
# From: https://huggingface.co/hakurei/waifu-diffusion-v1-3/resolve/main/wd-v1-3-float32.ckpt
# To: /content/stable-diffusion-webui/models/Stable-diffusion/waiffu_diffusion1_3.ckpt
# 100% 4.27G/4.27G [00:21<00:00, 197MB/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b2008eafaba2> in <module>
#     144     gpu = 'A100'
#     145
# --> 146   if (gpu=='T4'):
#     147     get_ipython().run_line_magic('pip', 'install https://github.com/daswer123/stable-diffusion-colab/raw/main/xformers%20prebuild/T4/python39/xformers-0.0.14.dev0-cp39-cp39-linux_x86_64.whl')
#     148
#
# NameError: name 'gpu' is not defined

# %%
import time
def getLink(path):
  with open(path, 'r') as testwritefile:
    webui_link = testwritefile.read()
    webui_link = webui_link[webui_link.rfind("http"):][:-1]
  return webui_link

# !fuser -k 5000/tcp
time.sleep(3)

share = "--deepdanbooru"


#@title ## Start (2) { display-mode: "form" }
#@markdown ###Do you want to use/leave the localtunnel?:
# %cd /content/stable-diffusion-webui
Use_Localtunnel = True #@param{type:"boolean"}

if (install_xformers):
  share = share + " --xformers"

#PREPARE
if Use_Localtunnel == True:
  share = share + " --api"

  # !nohup lt -p 7860 > lt.log 2>&1 &
  # !nohup lt -p 5000 > paint.log 2>&1 &
  time.sleep(3)
  if(outpaint_inpaint_module):
    webui_link = getLink('/content/stable-diffusion-webui/lt.log')
    # %cd /content/painthua-flask/templates
    # {"server":"some","canvas_w":0,"canvas_h":0}
    localStorageLine = '{"server":"'+webui_link+'"'
    # localStorageLine = (" ".join(localStorageLine.split()))

    localStorageLine ="        let serverURL = '"+localStorageLine+"'\n"
    replace_line("index.html",357,localStorageLine)

    # !nohup python /content/painthua-flask/app_colab.py > painthau.log 2>&1 &
    time.sleep(3)

    share = share + " --cors-allow-origins "+ getLink('/content/stable-diffusion-webui/paint.log')

#LOADING
    print("\033[94m INPAINT/OUTPAINT Module")
    print("Optional module for import/outpaint that is linked to webui")
    print("Before you start use it, visit webui link")
    print("If you want change model, first, change it in webui, it also change for this module")
    with open('/content/stable-diffusion-webui/paint.log', 'r') as testwritefile:
      print(testwritefile.read())

  print("\033[92m WEBUI")
  with open('/content/stable-diffusion-webui/lt.log', 'r') as testwritefile:
    print("\033[92m" + "Wait for the model to load and follow this link")
    print(testwritefile.read())
    print("\033[98m")

  # %cd /content/stable-diffusion-webui
  # !python launch.py $share

else:
  share = share + " --share"

  # %cd /content/stable-diffusion-webui
  # !python launch.py $share

# %% [markdown]
# # Extra

# %%
#@title STABLE DIFFUSION 2.1 (3) { display-mode: "form" }
# !pip install -q https://github.com/camenduru/stable-diffusion-webui-colab/releases/download/0.0.15/xformers-0.0.15.dev0+189828c.d20221207-cp38-cp38-linux_x86_64.whl

# !git clone https://github.com/camenduru/stable-diffusion-webui
# !git clone https://github.com/deforum-art/deforum-for-automatic1111-webui /content/stable-diffusion-webui/extensions/deforum-for-automatic1111-webui
# !git clone https://github.com/yfszzx/stable-diffusion-webui-images-browser /content/stable-diffusion-webui/extensions/stable-diffusion-webui-images-browser
# !git clone https://github.com/camenduru/stable-diffusion-webui-huggingface /content/stable-diffusion-webui/extensions/stable-diffusion-webui-huggingface
# %cd /content/stable-diffusion-webui

# !wget https://huggingface.co/stabilityai/stable-diffusion-2-1/resolve/main/v2-1_768-ema-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/v2-1_768-ema-pruned.ckpt
# !wget https://raw.githubusercontent.com/Stability-AI/stablediffusion/main/configs/stable-diffusion/v2-inference-v.yaml -O /content/stable-diffusion-webui/models/Stable-diffusion/v2-1_768-ema-pruned.yaml

# !python launch.py --share --force-enable-xformers

# %%
#@title  { display-mode: "form" }
#@title 
#@markdown ##Upload another model: (4)
Model = "waifu-diffusion 1.3 release" #@param ["Stable-diffusion 1.4","Stable-diffusion 1.5 + inpaint model","nai","Anything 3.0","BerryMix zeipher222", "waifu-diffusion 1.3 release"]

#@markdown ##Gdrive:
#@markdown #####If you select gdrive, the model will not be downloaded, but copied from your drive
mount_gdrive = False #@param{type:"boolean"}
#@markdown #####Write the folder or theass as path to the folder, you can leave the field blank if the model is in the root of the drive
gdrive_path = "SD_models/f222.ckpt" #@param {type:"string"}
#@markdown Your path look like /content/drive/MyDrive/**gdrive_path**


# %cd /content/stable-diffusion-webui
if mount_gdrive == True:
    new_gdrive_path = "/content/drive/MyDrive/" + gdrive_path
    # !cp $new_gdrive_path /content/stable-diffusion-webui/models/Stable-diffusion/
else:
    if(Model == "Stable-diffusion 1.4"):
      user_header = f"\"Authorization: Bearer {'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'}\""
      # !wget --header={user_header} https://huggingface.co/CompVis/stable-diffusion-v-1-4-original/resolve/main/sd-v1-4.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/model1_4.ckpt
    elif(Model == "Stable-diffusion 1.5 + inpaint model"):
      user_header = f"\"Authorization: Bearer {'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'}\""
      # !wget --header={user_header} https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5.ckpt
      # !wget --header={user_header} https://huggingface.co/runwayml/stable-diffusion-inpainting/resolve/main/sd-v1-5-inpainting.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5-inpainting.ckpt
      #VAE
      # !wget --header={user_header} https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5.vae.pt
      # !wget --header={user_header} https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5-inpainting.vae.pt
    elif(Model == "Anything 3.0"):
        # !gdown https://huggingface.co/Daswer123/misc_models/resolve/main/Anything-V3.0-pruned-fp32.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/anything3_0.ckpt
        # !gdown https://huggingface.co/Daswer123/misc_models/resolve/main/Anything-V3.0.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/anything3_0.vae.pt
    elif(Model == "BerryMix zeipher222"):
        # !gdown https://huggingface.co/Daswer123/misc_models/resolve/main/Anything-V3.0-pruned-fp32.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/BerryMix_zeipher222.ckpt
        # !gdown https://huggingface.co/Daswer123/misc_models/resolve/main/Anything-V3.0.vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/BerryMix_zeipher222.vae.pt
    elif(Model == "waifu-diffusion 1.3 release"):
        # !gdown https://huggingface.co/hakurei/waifu-diffusion-v1-3/resolve/main/wd-v1-3-float32.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/waiffu_diffusion1_3.ckpt
    elif(Model == "nai"):
        # !gdown https://huggingface.co/Daswer123/gfdsa/resolve/main/model.ckpt -O /content/stable-diffusion-webui/models/Stable-diffusion/nai.ckpt
        # !gdown https://huggingface.co/Daswer123/gfdsa/resolve/main/vae_vae.pt -O /content/stable-diffusion-webui/models/Stable-diffusion/nai.vae.pt
        # !gdown https://huggingface.co/Daswer123/raw/resolve/main/config.yaml -O /content/stable-diffusion-webui/models/Stable-diffusion/nai.yaml
        # !gdown https://huggingface.co/Daswer123/gfdsa/resolve/main/v2.pt -O /content/stable-diffusion-webui/v2.pt
        # !gdown https://huggingface.co/Daswer123/gfdsa/raw/main/v2enabler.py -O /content/stable-diffusion-webui/scripts/v2enable.py
        # %cd /content/stable-diffusion-webui
        # !wget https://pastebin.com/raw/ukEFznTb -O /content/stable-diffusion-webui/ui-config.json
        # !wget https://pastebin.com/raw/8u0Dw37P -O /content/stable-diffusion-webui/config.json
        # !git clone "https://github.com/DominikDoom/a1111-sd-webui-tagcomplete.git" extensions/tag-autocomplete
    else:
        # !gdown https://drive.google.com/uc?id=1EdZmlteF8EThBu9Rpf2JMRFSLbVD7EXa -O /content/stable-diffusion-webui/models/Stable-diffusion/model.ckpt

# %%
#@markdown ###If you did not install xformers right away, you can do it here
# %cd /content/stable-diffusion-webui/
# !mkdir repositories
# %cd /content/stable-diffusion-webui/repositories
# !git clone https://github.com/openai/triton.git
# %cd triton/python
# !pip install -e .

# %cd /notebooks/stable-diffusion-webui/repositories/
# !git clone https://github.com/facebookresearch/xformers.git
# %cd xformers
# !git submodule update --init --recursive
# !pip install -r requirements.txt

from IPython.display import clear_output
import time
from IPython.display import HTML
from subprocess import getoutput
import os
s = getoutput('nvidia-smi')
if 'T4' in s:
  gpu = 'T4'
elif 'P100' in s:
  gpu = 'P100'
elif 'V100' in s:
  gpu = 'V100'
elif 'A100' in s:
  gpu = 'A100'

if (gpu=='T4'):
  # %pip install -q https://github.com/daswer123/xformers_prebuild_wheels/raw/main/Google%20Collab/T4/python38/xformers-0.0.14.dev0-cp38-cp38-linux_x86_64.whl
  
elif (gpu=='P100'):
  # %pip install -q https://github.com/TheLastBen/fast-stable-diffusion/raw/main/precompiled/P100/xformers-0.0.13.dev0-py3-none-any.whl

elif (gpu=='V100'):
  # %pip install -q https://github.com/TheLastBen/fast-stable-diffusion/raw/main/precompiled/V100/xformers-0.0.13.dev0-py3-none-any.whl

elif (gpu=='A100'):
  # %pip install -q https://github.com/TheLastBen/fast-stable-diffusion/raw/main/precompiled/A100/xformers-0.0.13.dev0-py3-none-any.whl
install_xformers = True

# %%
#@markdown ###If you did not install hypernetwork modules right away, you can do it here

# %cd /content/stable-diffusion-webui/models/
# !gdown https://huggingface.co/Daswer123/gfdsa/resolve/main/hypernetworks.zip -O /content/stable-diffusion-webui/models/hypernetworks.zip 
# !unzip /content/stable-diffusion-webui/models/hypernetworks.zip

# %%
#@markdown ###Connect gdrive
from google.colab import drive
drive.mount('/content/drive')

# %%
#@markdown ### Install painthua inpaint/outpaint module
#painthua - inpaint outpaint module
outpaint_inpaint_module = True
if(outpaint_inpaint_module):
  # !pip install flask
  # %cd /content
  # !git clone https://github.com/daswer123/painthua-flask
  # %cd /content/painthua-flask
  # !nohup python app_colab.py > painthau.log 2>&1 &
